# %%
#imports 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import nltk

# %% [markdown]
# ## Data Preparation

# %%
albums = pd.read_csv('Data/Albums.csv', index_col=0).rename(columns = {'ID': 'Album ID'})
albums.head()
# Out:
#    Album ID                                             Albums
# 0    758025                       Speak Now (Taylor’s Version)
# 1   1040217                 Midnights (The Late Night Edition)
# 2   1040211                   Midnights (The Til Dawn Edition)
# 3   1027134  folklore: the long pond studio sessions (Recor...
# 4   1013719            The More Red (Taylor’s Version) Chapter

# %%
albums.shape #46 albums in total
# Out:
# (46, 2)

# %% [markdown]
# Create a df named `all_tracks` that has both track info and album info:

# %%
# create paths to the csv file of each album that contains songs and their IDs
album_paths = []
for album in albums['Albums']:
    album = re.sub(r"[^\w\s]", '_', album)
    album = re.sub(r"[\s]+", '', album)
    album_path = 'Data/Tabular/' + album + '.csv'
    album_paths.append(album_path)

album_paths[:5]
# Out:
# ['Data/Tabular/SpeakNow_Taylor_sVersion_.csv',
#  'Data/Tabular/Midnights_TheLateNightEdition_.csv',
#  'Data/Tabular/Midnights_TheTilDawnEdition_.csv',
#  'Data/Tabular/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_.csv',
#  'Data/Tabular/TheMoreRed_Taylor_sVersion_Chapter.csv']

# %%
# create the df
all_tracks = pd.DataFrame()
for idx, album in enumerate(albums['Albums']):
    # for each album, combine tracks and the album information together
    tracks = pd.read_csv(album_paths[idx], index_col = 0).rename(columns = {'ID': 'track_id', 'Tracks': 'track'})
    tracks['album_id'] = albums.loc[idx]['Album ID']
    tracks['album'] = albums.loc[idx]['Albums']

    # combine all albums and tracks
    all_tracks = pd.concat([tracks, all_tracks], ignore_index = True)

# %%
all_tracks
# Out:
#      track_id                                              track  album_id
# 0     8442190                                      Lavender Haze   1040211  \
# 1     8485907                                             Maroon   1040211
# 2     8434253                                          Anti-Hero   1040211
# 3     8445376                                  Snow On The Beach   1040211
# 4     8485908                             Youre On Your Own, Kid   1040211
# ..        ...                                                ...       ...
# 568   9199809  When Emma Falls in Love (Taylors Version) [Fro...    758025
# 569   4499979   I Can See You (Taylors Version) [From The Vault]    758025
# 570   4499925  Castles Crumbling (Taylors Version) [From The ...    758025
# 571   3947017     Foolish One (Taylors Version) [From The Vault]    758025
# 572   9199321        Timeless (Taylors Version) [From The Vault]    758025
#
#                                  album
# 0    Midnights (The Till Dawn Edition)
# 1    Midnights (The Till Dawn Edition)
# 2    Midnights (The Till Dawn Edition)
# 3    Midnights (The Till Dawn Edition)
# 4    Midnights (The Till Dawn Edition)
# ..                                 ...
# 568       Speak Now (Taylor’s Version)
# 569       Speak Now (Taylor’s Version)
# 570       Speak Now (Taylor’s Version)
# 571       Speak Now (Taylor’s Version)
# 572       Speak Now (Taylor’s Version)
#
# [573 rows x 4 columns]

# %% [markdown]
# To add the lyrics of a song to `all_tracks`, we need a directory path leading to the respective album folders containing the lyrics for their corresponding songs.

# %%
# create a dictionary where the key is a song track and the value corresponds to the album it belongs
track_album = {all_tracks.loc[idx]['track']:all_tracks.loc[idx]['album'] for idx in all_tracks.index}
list(track_album.items())[:5]
# Out:
# [('Lavender Haze', 'Midnights (The Late Night Edition)'),
#  ('Maroon', 'Midnights (The Late Night Edition)'),
#  ('Anti-Hero', 'Midnights (The Late Night Edition)'),
#  ('Snow On The Beach', 'Midnights (The Late Night Edition)'),
#  ('Youre On Your Own, Kid', 'Midnights (The Late Night Edition)')]

# %%
# create a dictionary where the key is an album name and the value is the path to the album folder
album_paths_cd = {}
for album in all_tracks['album'].unique():
    album_path = re.sub(r"[\s’]", '', album)
    album_path = re.sub(r"[^\w]", '_', album_path)
    album_paths_cd[album] = 'Data/Albums/' + album_path + '/'
list(album_paths_cd.items())[:5]
# Out:
# [('Midnights (The Till Dawn Edition)',
#   'Data/Albums/Midnights_TheTillDawnEdition_/'),
#  ('evermore: the dropped your hand while dancing chapter',
#   'Data/Albums/evermore_thedroppedyourhandwhiledancingchapter/'),
#  ('evermore: the “forever is the sweetest con” chapter',
#   'Data/Albums/evermore_the_foreveristhesweetestcon_chapter/'),
#  ('evermore (Japanese Edition)', 'Data/Albums/evermore_JapaneseEdition_/'),
#  ('evermore (deluxe version)', 'Data/Albums/evermore_deluxeversion_/')]

# %% [markdown]
# By leveraging the dictionaries above, we can derive the album directory path using the song track's name to access its associated lyric file.

# %%
lyric_paths = []
for idx in range(all_tracks['track'].shape[0]):
    # find path to the lyric file of each track
    track = all_tracks.loc[idx]['track']
    album = all_tracks.loc[idx]['album']
    lyric = re.sub(r"[\s]", '', track)
    lyric = re.sub(r"[^\w]", '_', lyric)
    lyric_paths.append(album_paths_cd[album] + lyric + '.txt')
lyric_paths[:5]
# Out:
# ['Data/Albums/Midnights_TheTillDawnEdition_/LavenderHaze.txt',
#  'Data/Albums/Midnights_TheTillDawnEdition_/Maroon.txt',
#  'Data/Albums/Midnights_TheTillDawnEdition_/Anti_Hero.txt',
#  'Data/Albums/Midnights_TheTillDawnEdition_/SnowOnTheBeach.txt',
#  'Data/Albums/Midnights_TheTillDawnEdition_/YoureOnYourOwn_Kid.txt']

# %% [markdown]
# combine the file `all_tracks` with the lyrics (if any).

# %%
lyric_ser = pd.Series(index = all_tracks.index)
for idx, path in enumerate(lyric_paths):
    try:
        with open(path, 'r') as f:
            txt = f.read()
            lyric_ser[idx] = txt
    except:
        lyric_ser[idx] = np.nan
        pass

# %%
all_tracks['lyrics'] = lyric_ser
all_tracks
# Out:
#      track_id                                              track  album_id
# 0     8442190                                      Lavender Haze   1040211  \
# 1     8485907                                             Maroon   1040211
# 2     8434253                                          Anti-Hero   1040211
# 3     8445376                                  Snow On The Beach   1040211
# 4     8485908                             Youre On Your Own, Kid   1040211
# ..        ...                                                ...       ...
# 568   9199809  When Emma Falls in Love (Taylors Version) [Fro...    758025
# 569   4499979   I Can See You (Taylors Version) [From The Vault]    758025
# 570   4499925  Castles Crumbling (Taylors Version) [From The ...    758025
# 571   3947017     Foolish One (Taylors Version) [From The Vault]    758025
# 572   9199321        Timeless (Taylors Version) [From The Vault]    758025
#
#                                  album
# 0    Midnights (The Till Dawn Edition)  \
# 1    Midnights (The Till Dawn Edition)
# 2    Midnights (The Till Dawn Edition)
# 3    Midnights (The Till Dawn Edition)
# 4    Midnights (The Till Dawn Edition)
# ..                                 ...
# 568       Speak Now (Taylor’s Version)
# 569       Speak Now (Taylor’s Version)
# 570       Speak Now (Taylor’s Version)
# 571       Speak Now (Taylor’s Version)
# 572       Speak Now (Taylor’s Version)
#
#                                                 lyrics
# 0    118 ContributorsTranslationsEspañolFrançaisPor...
# 1    131 ContributorsTranslationsEspañolTürkçeFranç...
# 2    192 ContributorsTranslationsPortuguêsEspañolTü...
# 3    143 ContributorsTranslationsPortuguêsEspañol中文...
# 4    137 ContributorsTranslationsEspañolFrançaisСрп...
# ..                                                 ...
# 568  79 ContributorsTranslationsPortuguêsItalianoFr...
# 569  86 ContributorsTranslationsPortuguêsItalianoFr...
# 570  45 ContributorsTranslationsPortuguêsItalianoFr...
# 571  57 ContributorsTranslationsPortuguêsItalianoFr...
# 572  49 ContributorsTranslationsPortuguêsItalianoFr...
#
# [573 rows x 5 columns]

# %% [markdown]
# The lyrics are messy. Let's clean it up.

# %%
cleaned_lyrics = []
for lyric in all_tracks['lyrics']:
    repl = re.sub(r'\[.*?\]', '', str(lyric)) # Remove lyric description: [Verse 1], [Chorus], etc.
    repl = re.sub(r'[\n+\d]', ' ', repl) # Remove newline characters and digits (all digits in lyrics are in words)
    repl = re.sub(r'.*Lyrics ', '', repl) # Remove the non-lyric first line
    repl = re.sub(r'\s+', ' ', repl) # Remove unnecessary whitespaces
    repl = re.sub(r' Embed', '', repl).strip() # Remove the non-lyric closing word
    cleaned_lyrics.append(repl)

# assign the cleaned lyrics back to `lyrics`
all_tracks['lyrics'] = cleaned_lyrics
all_tracks['lyrics'] = all_tracks['lyrics'].apply(lambda x: np.nan if x == 'nan' else x)

# %% [markdown]
# ## Missingness

# %% [markdown]
# Some songs do not have lyrics. Let's see what the songs are and what album do they belong to.

# %%
all_tracks.isnull().mean()
# Out:
# track_id    0.000000
# track       0.000000
# album_id    0.000000
# album       0.000000
# lyrics      0.097731
# dtype: float64

# %%
no_lyrics = all_tracks.loc[all_tracks.lyrics.isnull(), ['track', 'album']]
no_lyrics
# Out:
#                                            track
# 29                                cowboy like me  \
# 30                                    mirrorball
# 31                                      evermore
# 32                              long story short
# 33                              invisible string
# 34                                        willow
# 256                                        betty
# 257                                     dorothea
# 258                                     marjorie
# 259                                       august
# 260                            no body, no crime
# 261                      right where you left me
# 391                                     Carolina
# 392                     Carolina (Video Version)
# 507                                Lavender Haze
# 508                                       Maroon
# 509                                    Anti-Hero
# 510                            Snow On The Beach
# 511                       Youre On Your Own, Kid
# 512                                Midnight Rain
# 513                                 Question...?
# 514                               Vigilante Shit
# 515                                    Bejeweled
# 516                                    Labyrinth
# 517                                        Karma
# 518                                Sweet Nothing
# 519                                   Mastermind
# 520                                The Great War
# 521                    Bigger Than The Whole Sky
# 522                                        Paris
# 523                              High Infidelity
# 524                                       Glitch
# 525                   Wouldve, Couldve, Shouldve
# 526                                  Dear Reader
# 527                               Hits Different
# 528  Snow On The Beach (feat. More Lana Del Rey)
# 529                                Karma (Remix)
# 532                                    Anti-Hero
# 533                            Snow On The Beach
# 534                       Youre On Your Own, Kid
# 535                                Midnight Rain
# 536                                 Question...?
# 537                               Vigilante Shit
# 538                                    Bejeweled
# 539                                    Labyrinth
# 540                                        Karma
# 541                                Sweet Nothing
# 542                                   Mastermind
# 543                                The Great War
# 544                    Bigger Than The Whole Sky
# 545                              High Infidelity
# 546                   Wouldve, Couldve, Shouldve
# 547                                  Dear Reader
# 548             Youre Losing Me (From The Vault)
# 549  Snow On The Beach (feat. More Lana Del Rey)
# 550                                Karma (Remix)
#
#                                                  album
# 29   evermore: the “forever is the sweetest con” ch...
# 30   evermore: the “forever is the sweetest con” ch...
# 31   evermore: the “forever is the sweetest con” ch...
# 32   evermore: the “forever is the sweetest con” ch...
# 33   evermore: the “forever is the sweetest con” ch...
# 34   evermore: the “forever is the sweetest con” ch...
# 256                      the “ladies lunching” chapter
# 257                      the “ladies lunching” chapter
# 258                      the “ladies lunching” chapter
# 259                      the “ladies lunching” chapter
# 260                      the “ladies lunching” chapter
# 261                      the “ladies lunching” chapter
# 391  Carolina (From The Motion Picture “Where The C...
# 392  Carolina (From The Motion Picture “Where The C...
# 507                   Midnights (The Til Dawn Edition)
# 508                   Midnights (The Til Dawn Edition)
# 509                   Midnights (The Til Dawn Edition)
# 510                   Midnights (The Til Dawn Edition)
# 511                   Midnights (The Til Dawn Edition)
# 512                   Midnights (The Til Dawn Edition)
# 513                   Midnights (The Til Dawn Edition)
# 514                   Midnights (The Til Dawn Edition)
# 515                   Midnights (The Til Dawn Edition)
# 516                   Midnights (The Til Dawn Edition)
# 517                   Midnights (The Til Dawn Edition)
# 518                   Midnights (The Til Dawn Edition)
# 519                   Midnights (The Til Dawn Edition)
# 520                   Midnights (The Til Dawn Edition)
# 521                   Midnights (The Til Dawn Edition)
# 522                   Midnights (The Til Dawn Edition)
# 523                   Midnights (The Til Dawn Edition)
# 524                   Midnights (The Til Dawn Edition)
# 525                   Midnights (The Til Dawn Edition)
# 526                   Midnights (The Til Dawn Edition)
# 527                   Midnights (The Til Dawn Edition)
# 528                   Midnights (The Til Dawn Edition)
# 529                   Midnights (The Til Dawn Edition)
# 532                 Midnights (The Late Night Edition)
# 533                 Midnights (The Late Night Edition)
# 534                 Midnights (The Late Night Edition)
# 535                 Midnights (The Late Night Edition)
# 536                 Midnights (The Late Night Edition)
# 537                 Midnights (The Late Night Edition)
# 538                 Midnights (The Late Night Edition)
# 539                 Midnights (The Late Night Edition)
# 540                 Midnights (The Late Night Edition)
# 541                 Midnights (The Late Night Edition)
# 542                 Midnights (The Late Night Edition)
# 543                 Midnights (The Late Night Edition)
# 544                 Midnights (The Late Night Edition)
# 545                 Midnights (The Late Night Edition)
# 546                 Midnights (The Late Night Edition)
# 547                 Midnights (The Late Night Edition)
# 548                 Midnights (The Late Night Edition)
# 549                 Midnights (The Late Night Edition)
# 550                 Midnights (The Late Night Edition)

# %%
no_lyrics['album'].value_counts()
# Out:
# album
# Midnights (The Til Dawn Edition)                                23
# Midnights (The Late Night Edition)                              19
# evermore: the “forever is the sweetest con” chapter              6
# the “ladies lunching” chapter                                    6
# Carolina (From The Motion Picture “Where The Crawdads Sing”)     2
# Name: count, dtype: int64

# %%
for idx, track, album in no_lyrics.iterrows():
    no_lyrics[idx]['album'] =
# Out:
# (29, track                                       cowboy like me
# album    evermore: the “forever is the sweetest con” ch...
# Name: 29, dtype: object)
# (30, track                                           mirrorball
# album    evermore: the “forever is the sweetest con” ch...
# Name: 30, dtype: object)
# (31, track                                             evermore
# album    evermore: the “forever is the sweetest con” ch...
# Name: 31, dtype: object)
# (32, track                                     long story short
# album    evermore: the “forever is the sweetest con” ch...
# Name: 32, dtype: object)
# (33, track                                     invisible string
# album    evermore: the “forever is the sweetest con” ch...
# Name: 33, dtype: object)
# (34, track                                               willow
# album    evermore: the “forever is the sweetest con” ch...
# Name: 34, dtype: object)
# (256, track                            betty
# album    the “ladies lunching” chapter
# Name: 256, dtype: object)
# (257, track                         dorothea
# album    the “ladies lunching” chapter
# Name: 257, dtype: object)
# (258, track                         marjorie
# album    the “ladies lunching” chapter
# Name: 258, dtype: object)
# (259, track                           august
# album    the “ladies lunching” chapter
# Name: 259, dtype: object)
# (260, track                no body, no crime
# album    the “ladies lunching” chapter
# Name: 260, dtype: object)
# (261, track          right where you left me
# album    the “ladies lunching” chapter
# Name: 261, dtype: object)
# (391, track                                             Carolina
# album    Carolina (From The Motion Picture “Where The C...
# Name: 391, dtype: object)
# (392, track                             Carolina (Video Version)
# album    Carolina (From The Motion Picture “Where The C...
# Name: 392, dtype: object)
# (507, track                       Lavender Haze
# album    Midnights (The Til Dawn Edition)
# Name: 507, dtype: object)
# (508, track                              Maroon
# album    Midnights (The Til Dawn Edition)
# Name: 508, dtype: object)
# (509, track                           Anti-Hero
# album    Midnights (The Til Dawn Edition)
# Name: 509, dtype: object)
# (510, track                   Snow On The Beach
# album    Midnights (The Til Dawn Edition)
# Name: 510, dtype: object)
# (511, track              Youre On Your Own, Kid
# album    Midnights (The Til Dawn Edition)
# Name: 511, dtype: object)
# (512, track                       Midnight Rain
# album    Midnights (The Til Dawn Edition)
# Name: 512, dtype: object)
# (513, track                        Question...?
# album    Midnights (The Til Dawn Edition)
# Name: 513, dtype: object)
# (514, track                      Vigilante Shit
# album    Midnights (The Til Dawn Edition)
# Name: 514, dtype: object)
# (515, track                           Bejeweled
# album    Midnights (The Til Dawn Edition)
# Name: 515, dtype: object)
# (516, track                           Labyrinth
# album    Midnights (The Til Dawn Edition)
# Name: 516, dtype: object)
# (517, track                               Karma
# album    Midnights (The Til Dawn Edition)
# Name: 517, dtype: object)
# (518, track                       Sweet Nothing
# album    Midnights (The Til Dawn Edition)
# Name: 518, dtype: object)
# (519, track                          Mastermind
# album    Midnights (The Til Dawn Edition)
# Name: 519, dtype: object)
# (520, track                       The Great War
# album    Midnights (The Til Dawn Edition)
# Name: 520, dtype: object)
# (521, track           Bigger Than The Whole Sky
# album    Midnights (The Til Dawn Edition)
# Name: 521, dtype: object)
# (522, track                               Paris
# album    Midnights (The Til Dawn Edition)
# Name: 522, dtype: object)
# (523, track                     High Infidelity
# album    Midnights (The Til Dawn Edition)
# Name: 523, dtype: object)
# (524, track                              Glitch
# album    Midnights (The Til Dawn Edition)
# Name: 524, dtype: object)
# (525, track          Wouldve, Couldve, Shouldve
# album    Midnights (The Til Dawn Edition)
# Name: 525, dtype: object)
# (526, track                         Dear Reader
# album    Midnights (The Til Dawn Edition)
# Name: 526, dtype: object)
# (527, track                      Hits Different
# album    Midnights (The Til Dawn Edition)
# Name: 527, dtype: object)
# (528, track    Snow On The Beach (feat. More Lana Del Rey)
# album               Midnights (The Til Dawn Edition)
# Name: 528, dtype: object)
# (529, track                       Karma (Remix)
# album    Midnights (The Til Dawn Edition)
# Name: 529, dtype: object)
# (532, track                             Anti-Hero
# album    Midnights (The Late Night Edition)
# Name: 532, dtype: object)
# (533, track                     Snow On The Beach
# album    Midnights (The Late Night Edition)
# Name: 533, dtype: object)
# (534, track                Youre On Your Own, Kid
# album    Midnights (The Late Night Edition)
# Name: 534, dtype: object)
# (535, track                         Midnight Rain
# album    Midnights (The Late Night Edition)
# Name: 535, dtype: object)
# (536, track                          Question...?
# album    Midnights (The Late Night Edition)
# Name: 536, dtype: object)
# (537, track                        Vigilante Shit
# album    Midnights (The Late Night Edition)
# Name: 537, dtype: object)
# (538, track                             Bejeweled
# album    Midnights (The Late Night Edition)
# Name: 538, dtype: object)
# (539, track                             Labyrinth
# album    Midnights (The Late Night Edition)
# Name: 539, dtype: object)
# (540, track                                 Karma
# album    Midnights (The Late Night Edition)
# Name: 540, dtype: object)
# (541, track                         Sweet Nothing
# album    Midnights (The Late Night Edition)
# Name: 541, dtype: object)
# (542, track                            Mastermind
# album    Midnights (The Late Night Edition)
# Name: 542, dtype: object)
# (543, track                         The Great War
# album    Midnights (The Late Night Edition)
# Name: 543, dtype: object)
# (544, track             Bigger Than The Whole Sky
# album    Midnights (The Late Night Edition)
# Name: 544, dtype: object)
# (545, track                       High Infidelity
# album    Midnights (The Late Night Edition)
# Name: 545, dtype: object)
# (546, track            Wouldve, Couldve, Shouldve
# album    Midnights (The Late Night Edition)
# Name: 546, dtype: object)
# (547, track                           Dear Reader
# album    Midnights (The Late Night Edition)
# Name: 547, dtype: object)
# (548, track      Youre Losing Me (From The Vault)
# album    Midnights (The Late Night Edition)
# Name: 548, dtype: object)
# (549, track    Snow On The Beach (feat. More Lana Del Rey)
# album             Midnights (The Late Night Edition)
# Name: 549, dtype: object)
# (550, track                         Karma (Remix)
# album    Midnights (The Late Night Edition)
# Name: 550, dtype: object)

# %%
ser = all_tracks.loc[(all_tracks['track'] == 'Anti-Hero') & (~all_tracks['lyrics'].isnull()), 'lyrics']

# %%
ser.iloc[0][4:200] == ser.iloc[1][4:200]
# Out:
# False

# %%
for no_lyric_track in dic:
    all_tracks.loc[all_tracks['track'] == track, 'lyrics']
